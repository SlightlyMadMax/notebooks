# %% [markdown]
# ## Решение одномерной задачи Стефана
# Область - полубесконечная плоскость $x \in [0, \infty)$ в начальный момент заполненная водой при $T > T_m$. Граница $x = 0$ поддерживается при температуре $T < T_m$ в результате чего начинает образовываться лёд.
#
# В численных расчётах область задаётся конечной, но достаточно большой, чтобы на решении не сказывалось влияние границы.
#
# Граничные условия:
# $T(x,t)|_{x=0} = T_{ice} < T_m, \quad T(x,t)|_{x=\infty} = T_{water} > T_m$
#
# Начальное условие:
# $T(x, t)|_{t=0} = T_{water}$.
#
# $$
#     \frac{\partial (c T^*)}{\partial t} - \frac{\partial}{\partial x} \left(\frac{k}{\rho} \frac{\partial T^*}{\partial x}\right) + L\frac{\partial f}{\partial t} = 0.
# $$
#
# $$
#     x' = \frac{x}{H}, \quad t' = \frac{\alpha_l t}{H^2}, \quad T' = \frac{T^*}{\delta T}.
# $$
#
# $$
#     \frac{\partial (c' T)}{\partial t} - \frac{\partial}{\partial x} \left(k' \frac{\partial T}{\partial x}\right) + \frac{1}{Ste}\frac{\partial f}{\partial t} = 0.
# $$

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import fsolve
from scipy.special import erf

# %%
T_pt = 273.15
c_l = 4120.7
c_s = 2056.8
L = 3.33e5
rho = 999.84
k_l = 0.59
k_s = 2.21
alpha_l = k_l / (rho * c_l)
alpha_s = k_s / (rho * c_s)

T_s = 268.15
T_l = 278.15
delta_T = T_l - T_s
ste = c_l * delta_T / L

H = 5.0
n_x = 501
dx = H / (n_x - 1)

t_end = 60 * 60 * 24
n_t = 60 * 60 * 24
dt = t_end / n_t

T_init = np.full(n_x, fill_value=T_l)
T_init[0] = T_s

T_init_nd = (T_init - T_pt) / delta_T

# %% [markdown]
# ### Аналитическое решение

# %%
T_s_c = T_s - 273.15
T_l_c = T_l - 273.15
a_s = np.sqrt(alpha_s)
a_l = np.sqrt(alpha_l)

def trans_eq(gamma):
    lhs = (k_s * T_s_c * np.exp(-((gamma / (2.0 * a_s)) ** 2)) / (a_s * erf(gamma / (2.0 * a_s))))
    rhs = (-k_l * T_l_c * np.exp(-((gamma / (2.0 * a_l)) ** 2)) / (a_l * (1.0 - erf(gamma / (2.0 * a_l)))) - gamma * L * np.sqrt(np.pi) / 2)
    return lhs - rhs

gamma = fsolve(lambda x: trans_eq(gamma=x), 0.0002)[0]

s = t_end**0.5 * gamma

T_analytical = np.zeros(n_x)
x = np.linspace(0, H, n_x)

for i in range(n_x):
    if x[i] <= s:
        T_analytical[i] = T_s_c * (1.0 - erf(x[i] / (2.0 * a_s * t_end**0.5)) / erf(gamma / (2.0 * a_s)))
    else:
        T_analytical[i] = (T_l_c * (erf(x[i] / (2.0 * a_l * t_end**0.5)) - erf(gamma / (2.0 * a_l))) / (1.0 - erf(gamma / (2.0 * a_l))))

ax = plt.axes()
plt.plot(x[:int(n_x/5)], T_analytical[:int(n_x/5)], linewidth=1)
plt.plot(x[:int(n_x/5)], np.zeros(int(n_x/5)), color="black", linestyle='dashed')
plt.grid()
ax.set_title("Temperature distribution")
ax.set_xlabel("x, m")
ax.set_ylabel("Temperature, C")
plt.show()

# %% [markdown]
# ### Численное решение

# %% [markdown]
# $$
#     \frac{c^{n+1}_i T^{n+1}_i - c^{n}_i T^{n}_i}{\tau} - k^{n+1}_{i+1/2}\frac{T^{n+1}_{i+1} - T^{n+1}_i}{h} + k^{n+1}_{i-1/2}\frac{T^{n+1}_i - T^{n+1}_{i-1}}{h} + \frac{1}{Ste}\frac{f^{n+1}_i - f^{n}_i}{\tau} = 0
# $$
#
# $$
#     - \tau \frac{k^{n+1}_{i-1/2}}{h} T^{n+1}_{i-1} + \left( c^{n+1}_i + \tau \frac{k^{n+1}_{i-1/2} + k^{n+1}_{i+1/2}}{h} \right) T^{n+1}_i - \tau \frac{k^{n+1}_{i+1/2}}{h} T^{n+1}_{i+1} = c^{n}_i T^{n}_i - \frac{1}{\mathrm{Ste}} \left( f^{n+1}_i - f^{n}_i \right)
# $$

# %%
delta = 0.1 / delta_T # половина зоны двухфазного состояния обезразмеренная на delta_T
h = dx / H # обезразмеренный шаг по пространству
tau = dt * alpha_l / H**2 # обезразмеренный шаг по времени

def calculate_liquid_fraction(T: np.ndarray):
    return 0.5 * (1.0 + np.tanh(T / delta))

def calculate_c_eff(T: np.ndarray, liquid_frac: np.ndarray):
    c = c_s + liquid_frac * (c_l - c_s)
    return c / c_l

def calculate_k_eff(T: np.ndarray, liquid_frac: np.ndarray):
    k = k_s + liquid_frac * (k_l - k_s)
    return k / k_l

# %%
T_old = np.copy(T_init_nd)
T_k = np.copy(T_init_nd)
for n in range(1, n_t + 1):
    t = n * tau
